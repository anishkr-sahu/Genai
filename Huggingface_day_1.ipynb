# %% [markdown]
# <a href="https://colab.research.google.com/github/anishkr-sahu/Genai/blob/main/Huggingface_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hugging face

# %%
# !nvidia-smi
# Out:
# Tue Aug  4 03:57:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# install transformers
# !pip install transformers

# %%
# create a pipeline( it perform the nlp task)
from transformers import pipeline

# %%
# nlp task
# sentiment analysis
classifier = pipeline("text-classification")
result1 = classifier("The sun shone brightly, filling the whole room with warmth and light")
result2 = classifier("He tried his absolute best, but he could not finish the exam on time")
result3 = classifier("The sun shone brightly, filling the whole room with warmth and light")
print(result1)
print(result2)
print(result3)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9998729228973389}]
# [{'label': 'NEGATIVE', 'score': 0.9996174573898315}]
# [{'label': 'POSITIVE', 'score': 0.9998729228973389}]

# %%
from transformers import pipeline
import pandas as pd

# prepare table + question
data = {"Actors": ["Brad Pitt", "Leonardo Di Caprio", "George Clooney"], "Number of movies": ["87", "53", "69"]}
table = pd.DataFrame.from_dict(data)
question = "how many movies does Brad Pitt have?"

# pipeline model
# Note: you must to install torch-scatter first.
tqa = pipeline(task="table-question-answering", model="google/tapas-large-finetuned-wtq")

# result

print(tqa(table=table, query=question)['cells'][0])
#53
# Out:
# Loading weights:   0%|          | 0/403 [00:00<?, ?it/s]
# 87

# %%
from transformers import pipeline
import torch

generator = pipeline('text-generation', model = 'HuggingFaceH4/zephyr-7b-beta', torch_dtype=torch.float16, device_map="auto")
generator("Hello, I'm a language model", max_length = 30, num_return_sequences=2)
# Out:
# [transformers] Current model requires 512 bytes of buffer for offloaded layers, which seems does not fit any GPU's remaining memory. If you are experiencing a OOM later, please consider using offload_buffers=True.
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
# summarization
from transformers import pipeline

classifier = pipeline("summarization")
classifier("Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018, in an area of more than 105 square kilometres (41 square miles). The City of Paris is the centre and seat of government of the region and province of Île-de-France, or Paris Region, which has an estimated population of 12,174,880, or about 18 percent of the population of France as of 2017.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_421/371896875.py in <cell line: 0>()
#       2 from transformers import pipeline
#       3
# ----> 4 classifier = pipeline("summarization")
#       5 classifier("Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018, in an area of more than 105 square kilometres (41 square miles). The City of Paris is the centre and seat of government of the region and province of Île-de-France, or Paris Region, which has an estimated population of 12,174,880, or about 18 percent of the population of France as of 2017.")
#       6 ## [{ "summary_text": " Paris is the capital and most populous city of France..." }]
#
# ...

# %%
# Question and answering
from transformers import pipeline

qa_model = pipeline("question-answering")
question = "Where do I live?"
context = "My name is Merve and I live in İstanbul."
qa_model(question = question, context = context)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_421/3815503127.py in <cell line: 0>()
#       2 from transformers import pipeline
#       3
# ----> 4 qa_model = pipeline("question-answering")
#       5 question = "Where do I live?"
#       6 context = "My name is Merve and I live in İstanbul."
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     972             )
#     973     else:
# --> 974         normalized_task, targeted_task, task_options = check_task(task)
#     975         if pipeline_class is None:
#     976             pipeline_class = targeted_task["impl"]
#
# ...

# %%
# Token Classification
from transformers import pipeline
token_classifier = pipeline("token-classification")
token_classifier("Hello my name is anish!")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.33GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# ...
